# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("kc_house_data_cleaned.csv")

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.370842      2.114757
# std     6239.28002  2.876566e+09  3.671272e+05      0.930062      0.770163
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# std      918.440897  4.142051e+04      0.539989      0.086517      0.766318
# min      290.000000  5.200000e+02      1.000000      0.000000      0.000000
# 25%     1427.000000  5.040000e+03      1.000000      0.000000      0.000000
# 50%     1910.000000  7.618000e+03      1.500000      0.000000      0.000000
# 75%     2550.000000  1.068800e+04      2.000000      0.000000      0.000000
# max    13540.000000  1.651359e+06      3.500000      1.000000      4.000000
#
#        ...         grade    sqft_above  sqft_basement      yr_built  \
# count  ...  21613.000000  21613.000000   21613.000000  21613.000000
# mean   ...      7.656873   1788.390691     291.509045   1971.005136
# std    ...      1.175459    828.090978     442.575043     29.373411
# min    ...      1.000000    290.000000       0.000000   1900.000000
# 25%    ...      7.000000   1190.000000       0.000000   1951.000000
# 50%    ...      7.000000   1560.000000       0.000000   1975.000000
# 75%    ...      8.000000   2210.000000     560.000000   1997.000000
# max    ...     13.000000   9410.000000    4820.000000   2015.000000
#
#        yr_renovated       zipcode           lat          long  sqft_living15  \
# count  21613.000000  21613.000000  21613.000000  21613.000000   21613.000000
# mean      84.402258  98077.939805     47.560053   -122.213896    1986.552492
# std      401.679240     53.505026      0.138564      0.140828     685.391304
# min        0.000000  98001.000000     47.155900   -122.519000     399.000000
# 25%        0.000000  98033.000000     47.471000   -122.328000    1490.000000
# 50%        0.000000  98065.000000     47.571800   -122.230000    1840.000000
# 75%        0.000000  98118.000000     47.678000   -122.125000    2360.000000
# max     2015.000000  98199.000000     47.777600   -121.315000    6210.000000
#
#           sqft_lot15
# count   21613.000000
# mean    12768.455652
# std     27304.179631
# min       651.000000
# 25%      5100.000000
# 50%      7620.000000
# 75%     10083.000000
# max    871200.000000
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.sqft_living.hist()
# Out:
# <AxesSubplot:>

# %%
# sqft living space of 15 nearest neighbors
df.sqft_living15.hist()
# Out:
# <AxesSubplot:>

# %%
df.yr_built.hist()
# Out:
# <AxesSubplot:>

# %%
df.floors.hist()
# Out:
# <AxesSubplot:>

# %%
# index of 1-5 of home condition, 1 being poor, 5 being very good
df.condition.hist()
# Out:
# <AxesSubplot:>

# %%
# index of 1-13 on construction quality, 1 falling below standards, 7 being average and 13 being custom designed.
df.grade.hist()
# Out:
# <AxesSubplot:>

# %%
df.sqft_above.hist()
# Out:
# <AxesSubplot:>

# %%
df.sqft_basement.hist()
# Out:
# <AxesSubplot:>

# %%
df.zipcode.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['condition'])
# Out:
# <AxesSubplot:>

# %%
corr = df[['price', 'bedrooms', 'bathrooms',
           'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
           'grade']].corr()

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap = cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
corr = df[['price', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
           'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']].corr()

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap = cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df_cat = df[['condition', 'grade', 'zipcode', 'yr_built', 'yr_renovated']]
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
    plt.show()
# Out:
# graph for condition: total = 5
# graph for grade: total = 12
# graph for zipcode: total = 70
# graph for yr_built: total = 116
# graph for yr_renovated: total = 70

# %%
for i in df_cat[['yr_built']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
    plt.show()
# Out:
# graph for yr_built: total = 20

# %%
pd.pivot_table(df, index = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot'], values = 'price').sort_values('price', ascending = False)
# Out:
#                                              price
# bedrooms bathrooms sqft_living sqft_lot
# 6        8.00      12050       27600     7700000.0
# 5        4.50      10040       37325     7062500.0
# 6        7.75      9890        31374     6885000.0
# 5        5.75      9200        35069     5570000.0
#          5.00      8000        23985     5350000.0
# ...                                            ...
# 2        1.00      520         22334       82500.0
#                    730         9975        81000.0
# 1        0.75      430         5050        80000.0
# 2        1.00      780         16344       78000.0
# 1        0.00      670         43377       75000.0
#
# [21201 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['grade', 'condition', 'yr_built', 'yr_renovated'], values = 'price').sort_values('price', ascending = False)
# Out:
#                                            price
# grade condition yr_built yr_renovated
# 13    4         1910     1987          7700000.0
# 11    3         1940     2001          7062500.0
# 13    3         2001     0             5146000.0
# 12    3         1983     2009          4668000.0
#       4         1991     0             4250000.0
# ...                                          ...
# 4     3         1918     0               95000.0
# 5     1         1943     0               81000.0
# 4     2         1912     0               80000.0
# 5     1         1942     0               78000.0
# 3     3         1966     0               75000.0
#
# [2504 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['sqft_living15', 'sqft_living'], values = 'price').sort_values('price', ascending = False)
# Out:
#                                price
# sqft_living15 sqft_living
# 3940          12050        7700000.0
# 3930          10040        7062500.0
# 4540          9890         6885000.0
# 3560          9200         5570000.0
# 4600          8000         5350000.0
# ...                              ...
# 1572          520            82500.0
# 860           730            81000.0
# 1200          430            80000.0
# 1700          780            78000.0
# 1160          670            75000.0
#
# [15348 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['view', 'waterfront', 'zipcode'], values = 'price').sort_values('price', ascending = False)
# Out:
#                                 price
# view waterfront zipcode
# 2    1          98004    7.062500e+06
# 4    0          98039    6.885000e+06
# 3    0          98102    4.282500e+06
# 4    1          98105    3.650000e+06
#                 98039    3.640900e+06
# ...                               ...
# 0    0          98178    2.620739e+05
#                 98032    2.494135e+05
#                 98198    2.486485e+05
#                 98168    2.395656e+05
#                 98002    2.341037e+05
#
# [322 rows x 1 columns]
